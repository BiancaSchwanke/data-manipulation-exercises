# %% [markdown]
# ![](https://i.imgur.com/JsMvGnP.png)

# %% [markdown]
# ## Exercícios de manipulação de dados - Parte 4

# %% [markdown]
# Neste Jupyter notebook você irá resolver uma exercícios utilizando a biblioteca Pandas.\
# Todos os datasets utilizados nos exercícios estão salvos na pasta *datasets*.\
# Todo o seu código deve ser executado neste Jupyter Notebook. Por fim, se desejar, revise as respostas com o seu mentor.

# %% [markdown]
# #### Tarefa 1. Importe o dataset e salve os dados em um dataframe
#
# Os dados estão salvos no arquivo ***datasets/equatorial_empresas.csv***.\
# Este dataset contém informações sobre as empresas do Grupo Equatorial Energia, com colunas de segmento de atuação, estado, área de atuação (km²), número de clientes (em milhões) e ano de entrada no grupo.\
# Salve os dados em uma variável de nome *equatorial*.

# %%
# Seu código

# %% [markdown]
# #### Tarefa 2. Mostre as 5 primeiras linhas do dataset.

# %%
# Seu código

# %% [markdown]
# #### Tarefa 3. Quantas empresas (linhas) e quantas colunas existem no dataset?

# %%
# Seu código

# %% [markdown]
# #### Tarefa 4. Quais são os segmentos de atuação (coluna *segmento*) únicos presentes no dataset?
#
# *Dica: utilize a função unique()*

# %%
# Seu código

# %% [markdown]
# #### Tarefa 5. Quantas empresas atuam em cada segmento?
#
# *Dica: utilize a função value_counts()*

# %%
# Seu código

# %% [markdown]
# #### Tarefa 6. Filtre e mostre apenas as empresas do segmento "Distribuição de Energia".

# %%
# Seu código

# %% [markdown]
# #### Tarefa 7. Some o número total de clientes (em milhões), considerando apenas as empresas com esse dado informado.
#
# *Dica: valores ausentes (NaN) são ignorados automaticamente pela função sum()*

# %%
# Seu código

# %% [markdown]
# #### Tarefa 8. Ordene as empresas pela coluna *area_atuacao_km2* em ordem decrescente e mostre as 3 maiores.

# %%
# Seu código

# %% [markdown]
# #### Tarefa 9. Agrupe os dados por segmento e calcule a média de *clientes_milhoes* para cada um.
#
# *Dica: use a função groupby do Pandas na coluna segmento*

# %%
# Seu código

# %% [markdown]
# #### Tarefa 10. Quais empresas ainda não possuem o ano de entrada no grupo (*ano_entrada_grupo*) preenchido?
#
# *Dica: utilize a função isnull()*

# %%
# Seu código

# %% [markdown]
# #### Tarefa 11. Das empresas com o ano de entrada no grupo preenchido, qual foi a última a entrar no Grupo Equatorial?

# %%
# Seu código

# %% [markdown]
# **Parabéns! Você chegou ao fim!**
